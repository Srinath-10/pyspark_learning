# %%
from pyspark.sql import SparkSession

spark=SparkSession.builder.appName("learning").getOrCreate()

data = [("1", "101", "Laptop", 1200), ("2", "102", "Headphones", 150),
        ("3", "101", "Mouse", 25), ("4", "103", "Laptop", 1200),
        ("5", "104", "Monitor", 300)]
columns = ["Order_ID", "Customer_ID", "Product", "Price"]

df=spark.createDataFrame(data,schema=columns)
df.show()

# %%
# %sql
select * from samples.accuweather.forecast_daily_calendar_imperial limit 5

# %%
# %sql
-- The query below creates a new table.
-- Just hit "Run" to run the query or make any adjustments you like.
      -- Creating a sample diamonds table
      
      CREATE TABLE learning.default.diamonds (
          carat FLOAT,
          cut VARCHAR(10),
          color CHAR(1),
          clarity VARCHAR(4)
      );

      -- Inserting five rows of data
      INSERT INTO learning.default.diamonds (carat, cut, color, clarity) VALUES
          (0.23, 'Ideal', 'E', 'SI2'),
          (0.21, 'Premium', 'E', 'SI1'),
          (0.23, 'Good', 'E', 'VS1'),
          (0.29, 'Premium', 'I', 'VS2'),
          (0.31, 'Good', 'J', 'SI2');
